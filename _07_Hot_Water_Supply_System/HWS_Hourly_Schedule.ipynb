# %%
import sys
sys.path.append('../')
import nbimporter

from _11_Others import Life_Schedule as LS
# Out:
# Importing Jupyter notebook from ..\_11_Others\Life_Schedule.ipynb

# %% [markdown]
# # 付録 M 給湯使用及び入浴に関する毎時スケジュール

# %% [markdown]
# #### <center>表 M.1a-(1) 居住人数4人</center>
# <table>
#     <thead style="background-color:lightgrey" >
#         <tr>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=4 >時刻</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=8>休日在宅(大)</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=8>休日在宅(小)</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=8>平日(大)</th>
#         </tr>
#         <tr>
#             <!-- 休日在宅(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=6>基準給湯湯量(L/h)</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2 colspan=2>入浴<br/>人数<br/>(人/h)</th>
#             <!-- 休日在宅(小) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=6>基準給湯湯量(L/h)</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2 colspan=2>入浴<br/>人数<br/>(人/h)</th>
#             <!-- 平日(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=6>基準給湯湯量(L/h)</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2 colspan=2>入浴<br/>人数<br/>(人/h)</th>
#         </tr>
#         <tr>
#             <!-- 休日在宅(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2>台所<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=2>浴室<br/>シャワー<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2>洗面<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=2>浴槽<br/>湯はり</th>
#             <!-- 休日在宅(小) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2>台所<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=2>浴室<br/>シャワー<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2>洗面<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=2>浴槽<br/>湯はり</th>
#             <!-- 平日(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2>台所<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=2>浴室<br/>シャワー<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2>洗面<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=2>浴槽<br/>湯はり</th>
#         </tr>
#         <tr>
#             <!-- 浴室シャワー水栓 -->
#             <!-- 休日在宅(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 休日在宅(小) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 平日(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 浴槽湯はり -->
#             <!-- 休日在宅(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 休日在宅(小) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 平日(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 入力人数 -->
#             <!-- 休日在宅(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 休日在宅(小) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 平日(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">0時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">1時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">2時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">3時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">4時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">5時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">6時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">6</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">8</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">7時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">8</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">22</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">8時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">6</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">6</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">9時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">24</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">10時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">11時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">12時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">32</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">32</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">12</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">13時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td> <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">14時</td>
#              <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">15時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">16時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">17時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">44</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">32</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">18時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#              <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">16</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">30</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">19時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">180</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">180</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">10</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">180</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">20時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">74</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">50</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">6</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">1</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">50</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">50</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">1</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">56</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">50</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">1</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">21時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">90</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">6</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">1</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">50</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">1</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">50</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">1</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">22時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">100</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">6</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">100</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">100</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">23時</td>
#             <!-- 休日在宅(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">6</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日在宅(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(大) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# #### <center>表 M.1a-(2) 居住人数4人</center>
# <table>
#     <thead style="background-color:lightgrey" >
#         <tr>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=4 >時刻</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=8>平日(中)</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=8>平日(小)</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=8>休日外出</th>
#         </tr>
#         <tr>
#             <!-- 平日(中) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=6>基準給湯湯量(L/h)</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2 colspan=2>入浴<br/>人数<br/>(人/h)</th>
#             <!-- 平日(小) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=6>基準給湯湯量(L/h)</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2 colspan=2>入浴<br/>人数<br/>(人/h)</th>
#             <!-- 休日外出 -->
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=6>基準給湯湯量(L/h)</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2 colspan=2>入浴<br/>人数<br/>(人/h)</th>
#         </tr>
#         <tr>
#             <!-- 平日(中) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2>台所<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=2>浴室<br/>シャワー<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2>洗面<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=2>浴槽<br/>湯はり</th>
#             <!-- 平日(小) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2>台所<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=2>浴室<br/>シャワー<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2>洗面<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=2>浴槽<br/>湯はり</th>
#             <!-- 休日外出 -->
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2>台所<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=2>浴室<br/>シャワー<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2>洗面<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=2>浴槽<br/>湯はり</th>
#         </tr>
#         <tr>
#             <!-- 浴室シャワー水栓 -->
#             <!-- 平日(中) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 平日(小) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 休日外出 -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 浴槽湯はり -->
#             <!-- 平日(中) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 平日(小) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 休日外出 -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 入力人数 -->
#             <!-- 平日(中) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 平日(小) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 休日外出 -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">0時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">1時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">2時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">3時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">4時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">5時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">6時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">6</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">8</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">6</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">7時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">6</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">6</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">8時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">32</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">9時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">10時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">11時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">12時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">6</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">13時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">14時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">15時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">16時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">17時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">18時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">30</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">16</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">19時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">10</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">180</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">180</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">20時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">36</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">45</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">1</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">36</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">40</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">1</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">45</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">1</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">21時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">50</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">1</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">40</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">1</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">50</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">8</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">1</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">22時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">55</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">20</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">95</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">23時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">2</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし)-->
#             <td style="border:1px solid black; text-align:center;">4</td>  <!-- 洗面 　　　　　　　-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり)-->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし)-->
#         </tr>
#     </tbody>
# </table>

# %%
def get_WHS_Schedule(person, day, hour):
            
    data = {
        'p4' : {
            'SKD_W.HH_L' : { 
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   8, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  6, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' : 24, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' : 32, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   2, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   2, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' : 44, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   2, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  4, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :180, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' : 74, 'W_s_ari' : 50, 'W_s_nasi' : 0, 'W_w' :   6, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 1, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' : 90, 'W_s_nasi' : 0, 'W_w' :   6, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 1, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :100, 'W_s_nasi' : 0, 'W_w' :   6, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 2, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   6, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            }, 
            'SKD_W.HH_S' : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  6, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  4, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' : 32, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   2, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   2, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' : 32, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   2, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' : 16, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :180, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' : 50, 'W_s_ari' : 50, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 1, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' : 50, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 1, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :100, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 2, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            }, 
            'SKD_W.W_L'  : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  6, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   8, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' : 22, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   2, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   2, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' : 12, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   2, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   2, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' : 30, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   2, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' : 10, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :180, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' : 56, 'W_s_ari' : 50, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 1, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' : 50, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 1, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :100, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 2, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            }, 
            'SKD_W.W_M'  : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  6, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   8, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  4, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   2, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  6, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   2, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' : 30, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' : 10, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :180, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' : 36, 'W_s_ari' : 45, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 1, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' : 50, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 1, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' : 55, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 2, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            }, 
            'SKD_W.W_S'  : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  4, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  6, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' : 16, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :180, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' : 36, 'W_s_ari' : 40, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 1, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' : 40, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 1, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' : 20, 'W_s_nasi' : 0, 'W_w' :   2, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 2, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   2, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            }, 
            'SKD_W.HA'   : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   6, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   6, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' : 32, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' : 45, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 1, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' : 50, 'W_s_nasi' : 0, 'W_w' :   8, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 1, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' : 95, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 2, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   4, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            }
        }, 
        'p3' : {
            'SKD_W.HH_L' : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            }, 
            'SKD_W.HH_S' : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            }, 
            'SKD_W.W_L'  : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            }, 
            'SKD_W.W_M'  : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            },
            'SKD_W.W_S'  : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            },
            'SKD_W.HA'   : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            }        
        },
        'p2' : {
            'SKD_W.HH_L' : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            }, 
            'SKD_W.HH_S' : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            }, 
            'SKD_W.W_L'  : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            }, 
            'SKD_W.W_M'  : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            },
            'SKD_W.W_S'  : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            },
            'SKD_W.HA'   : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            } 
        },
        'p1' : {
            'SKD_W.HH_L' : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            }, 
            'SKD_W.HH_S' : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            }, 
            'SKD_W.W_L'  : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            }, 
            'SKD_W.W_M'  : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            },
            'SKD_W.W_S'  : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            },
            'SKD_W.HA'   : {
                 0 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 1 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 2 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 3 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 4 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 5 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 6 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 7 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 8 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                 9 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                10 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                11 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                12 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                13 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                14 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                15 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                16 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                17 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                18 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                19 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                20 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                21 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                22 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 },
                23 : {'W_k' :  0, 'W_s_ari' :  0, 'W_s_nasi' : 0, 'W_w' :   0, 'W_b_ari' :  0, 'W_b_nasi' : 0, 'n_b_ari' : 0, 'n_b_nasi' : 0 }
            } 
        }
    }
    
    return data[person]['SKD_W.' + LS.get_Schedule('HotWaterSupply', day).name][hour]

# %%
get_WHS_Schedule('p4', '1/1', 8)
# Out:
# {'W_b_ari': 0,
#  'W_b_nasi': 0,
#  'W_k': 6,
#  'W_s_ari': 0,
#  'W_s_nasi': 0,
#  'W_w': 4,
#  'n_b_ari': 0,
#  'n_b_nasi': 0}

# %%
# 4人(浴室等あり)
print('台所    [L/day]  = ' + str([sum([get_WHS_Schedule('p4', day, hour)['W_k']     for hour in range(0, 24, 1)]) for day in ['1/1', '1/7', '1/11', '1/4', '1/3', '1/8']]))
print('シャワー[L/day]  = ' + str([sum([get_WHS_Schedule('p4', day, hour)['W_s_ari'] for hour in range(0, 24, 1)]) for day in ['1/1', '1/7', '1/11', '1/4', '1/3', '1/8']]))
print('洗面    [L/day]  = ' + str([sum([get_WHS_Schedule('p4', day, hour)['W_w']     for hour in range(0, 24, 1)]) for day in ['1/1', '1/7', '1/11', '1/4', '1/3', '1/8']]))
print('湯はり  [L/day]  = ' + str([sum([get_WHS_Schedule('p4', day, hour)['W_b_ari'] for hour in range(0, 24, 1)]) for day in ['1/1', '1/7', '1/11', '1/4', '1/3', '1/8']]))
print('入浴人数[人/day] = ' + str([sum([get_WHS_Schedule('p4', day, hour)['n_b_ari'] for hour in range(0, 24, 1)]) for day in ['1/1', '1/7', '1/11', '1/4', '1/3', '1/8']]))
# Out:
# 台所    [L/day]  = [184, 140, 136, 92, 62, 32]
# シャワー[L/day]  = [240, 200, 200, 150, 100, 190]
# 洗面    [L/day]  = [46, 30, 34, 28, 8, 28]
# 湯はり  [L/day]  = [180, 180, 180, 180, 180, 0]
# 入浴人数[人/day] = [4, 4, 4, 4, 4, 4]

# %%
# 4人(浴室等なし)
print('台所    [L/day]  = ' + str([sum([get_WHS_Schedule('p4', day, hour)['W_k']      for hour in range(0, 24, 1)]) for day in ['1/1', '1/7', '1/11', '1/4', '1/3', '1/8']]))
print('シャワー[L/day]  = ' + str([sum([get_WHS_Schedule('p4', day, hour)['W_s_nasi'] for hour in range(0, 24, 1)]) for day in ['1/1', '1/7', '1/11', '1/4', '1/3', '1/8']]))
print('洗面    [L/day]  = ' + str([sum([get_WHS_Schedule('p4', day, hour)['W_w']      for hour in range(0, 24, 1)]) for day in ['1/1', '1/7', '1/11', '1/4', '1/3', '1/8']]))
print('湯はり  [L/day]  = ' + str([sum([get_WHS_Schedule('p4', day, hour)['W_b_nasi'] for hour in range(0, 24, 1)]) for day in ['1/1', '1/7', '1/11', '1/4', '1/3', '1/8']]))
print('入浴人数[人/day] = ' + str([sum([get_WHS_Schedule('p4', day, hour)['n_b_nasi'] for hour in range(0, 24, 1)]) for day in ['1/1', '1/7', '1/11', '1/4', '1/3', '1/8']]))
# Out:
# 台所    [L/day]  = [184, 140, 136, 92, 62, 32]
# シャワー[L/day]  = [0, 0, 0, 0, 0, 0]
# 洗面    [L/day]  = [46, 30, 34, 28, 8, 28]
# 湯はり  [L/day]  = [0, 0, 0, 0, 0, 0]
# 入浴人数[人/day] = [0, 0, 0, 0, 0, 0]

# %% [markdown]
# ### テンプレート
# <table>
#     <thead style="background-color:lightgrey" >
#         <tr>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=4 >時刻</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=8>休日在宅(大)</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=8>休日在宅(小)</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=8>平日(大)</th>
#         </tr>
#         <tr>
#             <!-- 休日在宅(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=6>基準給湯湯量(L/h)</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2 colspan=2>入浴<br/>人数<br/>(人/h)</th>
#             <!-- 休日在宅(小) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=6>基準給湯湯量(L/h)</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2 colspan=2>入浴<br/>人数<br/>(人/h)</th>
#             <!-- 平日(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=6>基準給湯湯量(L/h)</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2 colspan=2>入浴<br/>人数<br/>(人/h)</th>
#         </tr>
#         <tr>
#             <!-- 休日在宅(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2>台所<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=2>浴室<br/>シャワー<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2>洗面<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=2>浴槽<br/>湯はり</th>
#             <!-- 休日在宅(小) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2>台所<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=2>浴室<br/>シャワー<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2>洗面<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=2>浴槽<br/>湯はり</th>
#             <!-- 平日(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2>台所<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=2>浴室<br/>シャワー<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" rowspan=2>洗面<br/>水栓</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;" colspan=2>浴槽<br/>湯はり</th>
#         </tr>
#         <tr>
#             <!-- 浴室シャワー水栓 -->
#             <!-- 休日在宅(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 休日在宅(小) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 平日(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 浴槽湯はり -->
#             <!-- 休日在宅(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 休日在宅(小) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 平日(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 入力人数 -->
#             <!-- 休日在宅(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 休日在宅(小) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#             <!-- 平日(大) -->
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ある<br/>場合</th>
#             <th style="text-align:center; text-align:center; border:1px solid black;">浴室<br/>等が<br/>ない<br/>場合</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">0時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">1時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">2時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">3時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">4時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">5時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">6時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">7時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">8時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">9時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">10時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">11時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">12時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">13時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">14時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">15時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">16時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">17時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">18時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">19時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">20時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">21時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">22時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#         <tr>
#             <td style="border:1px solid black; text-align:center;">23時</td>
#             <!-- 平日(中) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 平日(小) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#             <!-- 休日外出 -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 台所 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- シャワー(浴室等なし) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 洗面 　　　　　　　  -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等あり)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 湯はり(浴室等なし)   -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等あり) -->
#             <td style="border:1px solid black; text-align:center;">0</td>  <!-- 入浴人数(浴室等なし) -->
#         </tr>
#     </tbody>
# </table>
